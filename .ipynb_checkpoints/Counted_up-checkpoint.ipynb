# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import sys
import os
# !head -n 3 data.txt
# Out:
# Genesis 1:1	In the beginning God created the heaven and the earth.
# Genesis 1:2	And the earth was without form, and void; and darkness was upon the face of the deep. And the Spirit of God moved upon the face of the waters.
# Genesis 1:3	And God said, Let there be light: and there was light.

# %%
data_col=['book_bible','verse', 'extra']

# %%
df_text = pd.read_fwf('data.txt', sep=" ", colspecs='infer', names=data_col, widths=None, squeeze=True, header=None)
# df_text = pd.read_fwf('data.txt',colspecs='infer')

# %%
df_text.describe()
# Out:
#        book_bible                        verse extra
# count       31102                        31102  1076
# unique        311                        31090   845
# top        Psalms  Then Job answered and said,     .
# freq         2461                            4    29

# %%
df_text.head(3)
# Out:
#   book_bible                                              verse extra
# 0    Genesis  1:1\tIn the beginning God created the heaven a...   NaN
# 1    Genesis  1:2\tAnd the earth was without form, and void;...   NaN
# 2    Genesis  1:3\tAnd God said, Let there be light: and the...   NaN

# %%
df_text.tail(3)
# Out:
#       book_bible                                              verse extra
# 31099    Revelat  on 22:19\tAnd if any man shall take away from ...   NaN
# 31100    Revelat  on 22:20\tHe which testifieth these things sai...   NaN
# 31101    Revelat  on 22:21\tThe grace of our Lord Jesus Christ b...   NaN

# %%
del df_text['extra']

# %%
books_old_testament = ["Genesis","Exodus","Leviticus","Numbers","Deuteronomy","Joshua","Judges","Ruth","1 Samuel",
                       "2 Samuel","1 Kings","2 Kings","1 Chronicles","2 Chronicles","Ezra","Nehemiah","Esther","Job",
                       "Psalms","Proverbs","Ecclesiastes","Song of Solomon","Isaiah","Jeremiah","Lamentations","Ezekiel",
                       "Daniel","Hosea","Joel","Amos","Obadiah","Jonah","Micah","Nahum","Habakkuk","Zephaniah","Haggai",
                       "Zechariah","Malachi"]

# %%
books_new_testament = ["Matthew","Mark","Luke","John","Acts of Apostles","Romans","1 Corinthians","2 Corinthians",
                      "Galatians","Ephesians","Philippians","Colossians","1 Thessalonians","2 Thessalonians","1 Timothy",
                      "2 Timothy","Titus","Philemon","Hebrews","James","1 Peter","2 Peter","1 John","2 John","3 John",
                      "Jude","Revelation"]

# %%
df_text.columns
# Out:
# Index(['book_bible', 'verse'], dtype='object')

# %%
df_verses = df_text['verse']

# %%
df_verses.head(3)
# Out:
# 0    1:1\tIn the beginning God created the heaven a...
# 1    1:2\tAnd the earth was without form, and void;...
# 2    1:3\tAnd God said, Let there be light: and the...
# Name: verse, dtype: object

# %%
for row in df_verses:
    print(row)
    break
# Out:
# 1:1	In the beginning God created the heaven and the earth.

# %%
# global _counted
# _counted = {}
# count = 0

# %%
_counted = dict()
count = 0

for row in df_verses:
    stringed = str(row)
#     Clean each line - Remove punctuations
    pos = stringed.find('\t')
    stringed = stringed[pos:]
#     print(stringed)

    stringed = stringed.replace(",","")
    stringed = stringed.replace(";","")
    stringed = stringed.replace(".","")
    stringed = stringed.replace("?","")
    stringed = stringed.replace("!","")
    stringed = stringed.replace("(","")
    stringed = stringed.replace(")","")
#     stringed = stringed.replace("\t"," ")
    stringed = stringed.strip()
    collects = list(stringed.split(" "))

    for item in collects:
        if '\t' in item:
            item = item.replace('\t',' ')
        if item not in ['God','Jesus', 'Lord']:
            item = item.lower()
            
        if item in ['in', 'and', 'the', 'then','on', 'is', 'from']:
            continue
            
        if ":" in item:
            continue
        
        if item == '':
            continue
            
        try:
            _counted[item] = _counted[item] + 1
        except KeyError:
            _counted[item] = 1

# %%
# sorted(_counted)
over_1000 = dict()

for key in _counted.keys():
    if _counted[key] > 300:
        over_1000['{}'.format(key)] = _counted[key]
        

print(len(over_1000))
# Out:
# 276

# %%
# sorted(_counted.values())
plt.bar(range(len(over_1000)), over_1000.values(), align="center", color="g")
plt.xticks(range(len(over_1000)), list(over_1000.keys()))
# Out:
# ([<matplotlib.axis.XTick at 0x116184978>,
#   <matplotlib.axis.XTick at 0x115e14fd0>,
#   <matplotlib.axis.XTick at 0x115e14a90>,
#   <matplotlib.axis.XTick at 0x11642cb38>,
#   <matplotlib.axis.XTick at 0x1164310f0>,
#   <matplotlib.axis.XTick at 0x116431588>,
#   <matplotlib.axis.XTick at 0x116431ac8>,
#   <matplotlib.axis.XTick at 0x116431b70>,
#   <matplotlib.axis.XTick at 0x116431e80>,
#   <matplotlib.axis.XTick at 0x11643e4e0>,
#   <matplotlib.axis.XTick at 0x11643ea20>,
#   <matplotlib.axis.XTick at 0x11643ef28>,
#   <matplotlib.axis.XTick at 0x116446470>,
#   <matplotlib.axis.XTick at 0x116446978>,
#   <matplotlib.axis.XTick at 0x116446eb8>,
#   <matplotlib.axis.XTick at 0x11644f4a8>,
#   <matplotlib.axis.XTick at 0x116446fd0>,
#   <matplotlib.axis.XTick at 0x11643e588>,
#   <matplotlib.axis.XTick at 0x11644f550>,
#   <matplotlib.axis.XTick at 0x11644fda0>,
#   <matplotlib.axis.XTick at 0x116452320>,
#   <matplotlib.axis.XTick at 0x116452828>,
#   <matplotlib.axis.XTick at 0x116452d30>,
#   <matplotlib.axis.XTick at 0x1164582b0>,
#   <matplotlib.axis.XTick at 0x1164587f0>,
#   <matplotlib.axis.XTick at 0x116452630>,
#   <matplotlib.axis.XTick at 0x11644f470>,
#   <matplotlib.axis.XTick at 0x116458ef0>,
#   <matplotlib.axis.XTick at 0x11645d208>,
#   <matplotlib.axis.XTick at 0x11645d710>,
#   <matplotlib.axis.XTick at 0x11645dc18>,
#   <matplotlib.axis.XTick at 0x1164641d0>,
#   <matplotlib.axis.XTick at 0x1164646d8>,
#   <matplotlib.axis.XTick at 0x116464be0>,
#   <matplotlib.axis.XTick at 0x11646a160>,
#   <matplotlib.axis.XTick at 0x116464240>,
#   <matplotlib.axis.XTick at 0x116458f98>,
#   <matplotlib.axis.XTick at 0x11646a470>,
#   <matplotlib.axis.XTick at 0x11646a978>,
#   <matplotlib.axis.XTick at 0x11646af28>,
#   <matplotlib.axis.XTick at 0x116472518>,
#   <matplotlib.axis.XTick at 0x116472a20>,
#   <matplotlib.axis.XTick at 0x116472f28>,
#   <matplotlib.axis.XTick at 0x1164774a8>,
#   <matplotlib.axis.XTick at 0x116472e80>,
#   <matplotlib.axis.XTick at 0x11646a550>,
#   <matplotlib.axis.XTick at 0x116477978>,
#   <matplotlib.axis.XTick at 0x116477d30>,
#   <matplotlib.axis.XTick at 0x11647d278>,
#   <matplotlib.axis.XTick at 0x11647d7b8>,
#   <matplotlib.axis.XTick at 0x11647dcc0>,
#   <matplotlib.axis.XTick at 0x116484208>,
#   <matplotlib.axis.XTick at 0x116484710>,
#   <matplotlib.axis.XTick at 0x11647d780>,
#   <matplotlib.axis.XTick at 0x116477400>,
#   <matplotlib.axis.XTick at 0x116484e80>,
#   <matplotlib.axis.XTick at 0x11648e160>,
#   <matplotlib.axis.XTick at 0x11648e5f8>,
#   <matplotlib.axis.XTick at 0x11648eb38>,
#   <matplotlib.axis.XTick at 0x116491160>,
#   <matplotlib.axis.XTick at 0x1164916a0>,
#   <matplotlib.axis.XTick at 0x116491b70>,
#   <matplotlib.axis.XTick at 0x116498128>,
#   <matplotlib.axis.XTick at 0x1164914e0>,
#   <matplotlib.axis.XTick at 0x116484eb8>,
#   <matplotlib.axis.XTick at 0x116498400>,
#   <matplotlib.axis.XTick at 0x116498908>,
#   <matplotlib.axis.XTick at 0x116498e80>,
#   <matplotlib.axis.XTick at 0x11649e3c8>,
#   <matplotlib.axis.XTick at 0x11649e908>,
#   <matplotlib.axis.XTick at 0x11649ee10>,
#   <matplotlib.axis.XTick at 0x1164a33c8>,
#   <matplotlib.axis.XTick at 0x11649eef0>,
#   <matplotlib.axis.XTick at 0x1164984a8>,
#   <matplotlib.axis.XTick at 0x1164a3908>,
#   <matplotlib.axis.XTick at 0x1164a3cf8>,
#   <matplotlib.axis.XTick at 0x1164ab278>,
#   <matplotlib.axis.XTick at 0x1164ab7b8>,
#   <matplotlib.axis.XTick at 0x1164abd68>,
#   <matplotlib.axis.XTick at 0x1164b2320>,
#   <matplotlib.axis.XTick at 0x1164b2898>,
#   <matplotlib.axis.XTick at 0x1164b2e10>,
#   <matplotlib.axis.XTick at 0x1164abb00>,
#   <matplotlib.axis.XTick at 0x1164a32e8>,
#   <matplotlib.axis.XTick at 0x1164b82b0>,
#   <matplotlib.axis.XTick at 0x1164b8860>,
#   <matplotlib.axis.XTick at 0x1164b8e48>,
#   <matplotlib.axis.XTick at 0x1164bd390>,
#   <matplotlib.axis.XTick at 0x1164bd8d0>,
#   <matplotlib.axis.XTick at 0x1164bddd8>,
#   <matplotlib.axis.XTick at 0x1164c7438>,
#   <matplotlib.axis.XTick at 0x1164bd2e8>,
#   <matplotlib.axis.XTick at 0x116491ac8>,
#   <matplotlib.axis.XTick at 0x1164c77f0>,
#   <matplotlib.axis.XTick at 0x1164c7d68>,
#   <matplotlib.axis.XTick at 0x1164ca358>,
#   <matplotlib.axis.XTick at 0x1164ca940>,
#   <matplotlib.axis.XTick at 0x1164cae80>,
#   <matplotlib.axis.XTick at 0x1164d2400>,
#   <matplotlib.axis.XTick at 0x1164d2908>,
#   <matplotlib.axis.XTick at 0x1164caf60>,
#   <matplotlib.axis.XTick at 0x1164a3dd8>,
#   <matplotlib.axis.XTick at 0x1164d2710>,
#   <matplotlib.axis.XTick at 0x1164d8208>,
#   <matplotlib.axis.XTick at 0x1164d8710>,
#   <matplotlib.axis.XTick at 0x1164d8c88>,
#   <matplotlib.axis.XTick at 0x1164df1d0>,
#   <matplotlib.axis.XTick at 0x1164df710>,
#   <matplotlib.axis.XTick at 0x1164dfc18>,
#   <matplotlib.axis.XTick at 0x1164df7b8>,
#   <matplotlib.axis.XTick at 0x1164d8a58>,
#   <matplotlib.axis.XTick at 0x1164c77b8>,
#   <matplotlib.axis.XTick at 0x1164e45c0>,
#   <matplotlib.axis.XTick at 0x1164e4b70>,
#   <matplotlib.axis.XTick at 0x1164ec198>,
#   <matplotlib.axis.XTick at 0x1164ec630>,
#   <matplotlib.axis.XTick at 0x1164ecb38>,
#   <matplotlib.axis.XTick at 0x1164f00f0>,
#   <matplotlib.axis.XTick at 0x1164f0588>,
#   <matplotlib.axis.XTick at 0x1164ec4a8>,
#   <matplotlib.axis.XTick at 0x1164e4588>,
#   <matplotlib.axis.XTick at 0x1164b2c50>,
#   <matplotlib.axis.XTick at 0x116458d30>,
#   <matplotlib.axis.XTick at 0x1164f0a20>,
#   <matplotlib.axis.XTick at 0x1164f0f60>,
#   <matplotlib.axis.XTick at 0x1164f7518>,
#   <matplotlib.axis.XTick at 0x1164f7a58>,
#   <matplotlib.axis.XTick at 0x1164fa0f0>,
#   <matplotlib.axis.XTick at 0x1164f75f8>,
#   <matplotlib.axis.XTick at 0x1164f07b8>,
#   <matplotlib.axis.XTick at 0x1164ec438>,
#   <matplotlib.axis.XTick at 0x1164fa908>,
#   <matplotlib.axis.XTick at 0x1164fae80>,
#   <matplotlib.axis.XTick at 0x116501470>,
#   <matplotlib.axis.XTick at 0x1165019b0>,
#   <matplotlib.axis.XTick at 0x116501eb8>,
#   <matplotlib.axis.XTick at 0x116508400>,
#   <matplotlib.axis.XTick at 0x116508908>,
#   <matplotlib.axis.XTick at 0x1165013c8>,
#   <matplotlib.axis.XTick at 0x1164f7080>,
#   <matplotlib.axis.XTick at 0x116508c88>,
#   <matplotlib.axis.XTick at 0x116516208>,
#   <matplotlib.axis.XTick at 0x116516748>,
#   <matplotlib.axis.XTick at 0x116516c88>,
#   <matplotlib.axis.XTick at 0x11651b208>,
#   <matplotlib.axis.XTick at 0x11651b780>,
#   <matplotlib.axis.XTick at 0x11651bd30>,
#   <matplotlib.axis.XTick at 0x11651be10>,
#   <matplotlib.axis.XTick at 0x116516550>,
#   <matplotlib.axis.XTick at 0x116501550>,
#   <matplotlib.axis.XTick at 0x116522668>,
#   <matplotlib.axis.XTick at 0x116522ba8>,
#   <matplotlib.axis.XTick at 0x116526198>,
#   <matplotlib.axis.XTick at 0x116526668>,
#   <matplotlib.axis.XTick at 0x116526b70>,
#   <matplotlib.axis.XTick at 0x11652e160>,
#   <matplotlib.axis.XTick at 0x1165265c0>,
#   <matplotlib.axis.XTick at 0x116522710>,
#   <matplotlib.axis.XTick at 0x11652e4e0>,
#   <matplotlib.axis.XTick at 0x11652ea58>,
#   <matplotlib.axis.XTick at 0x11652ee80>,
#   <matplotlib.axis.XTick at 0x116534518>,
#   <matplotlib.axis.XTick at 0x116534a90>,
#   <matplotlib.axis.XTick at 0x116534e80>,
#   <matplotlib.axis.XTick at 0x11653c5f8>,
#   <matplotlib.axis.XTick at 0x11653cac8>,
#   <matplotlib.axis.XTick at 0x1165342e8>,
#   <matplotlib.axis.XTick at 0x116522b00>,
#   <matplotlib.axis.XTick at 0x11653ce80>,
#   <matplotlib.axis.XTick at 0x1165403c8>,
#   <matplotlib.axis.XTick at 0x1165409b0>,
#   <matplotlib.axis.XTick at 0x116540ef0>,
#   <matplotlib.axis.XTick at 0x1165464a8>,
#   <matplotlib.axis.XTick at 0x1165469b0>,
#   <matplotlib.axis.XTick at 0x116546ef0>,
#   <matplotlib.axis.XTick at 0x116546e48>,
#   <matplotlib.axis.XTick at 0x1165404e0>,
#   <matplotlib.axis.XTick at 0x11654a320>,
#   <matplotlib.axis.XTick at 0x11654a7f0>,
#   <matplotlib.axis.XTick at 0x11654ad30>,
#   <matplotlib.axis.XTick at 0x116557320>,
#   <matplotlib.axis.XTick at 0x1165578d0>,
#   <matplotlib.axis.XTick at 0x116557e48>,
#   <matplotlib.axis.XTick at 0x11655f438>,
#   <matplotlib.axis.XTick at 0x1165576a0>,
#   <matplotlib.axis.XTick at 0x11654a8d0>,
#   <matplotlib.axis.XTick at 0x11655f828>,
#   <matplotlib.axis.XTick at 0x11655fe80>,
#   <matplotlib.axis.XTick at 0x116565438>,
#   <matplotlib.axis.XTick at 0x1165659e8>,
#   <matplotlib.axis.XTick at 0x116565e80>,
#   <matplotlib.axis.XTick at 0x11656c518>,
#   <matplotlib.axis.XTick at 0x11656ca58>,
#   <matplotlib.axis.XTick at 0x11656ccc0>,
#   <matplotlib.axis.XTick at 0x11656c2e8>,
#   <matplotlib.axis.XTick at 0x11655fe10>,
#   <matplotlib.axis.XTick at 0x116571358>,
#   <matplotlib.axis.XTick at 0x116571940>,
#   <matplotlib.axis.XTick at 0x116571c50>,
#   <matplotlib.axis.XTick at 0x116577668>,
#   <matplotlib.axis.XTick at 0x116577be0>,
#   <matplotlib.axis.XTick at 0x11657e198>,
#   <matplotlib.axis.XTick at 0x11657e668>,
#   <matplotlib.axis.XTick at 0x116577f98>,
#   <matplotlib.axis.XTick at 0x116571320>,
#   <matplotlib.axis.XTick at 0x11657e5c0>,
#   <matplotlib.axis.XTick at 0x11657eeb8>,
#   <matplotlib.axis.XTick at 0x116585518>,
#   <matplotlib.axis.XTick at 0x116585a58>,
#   <matplotlib.axis.XTick at 0x116585f60>,
#   <matplotlib.axis.XTick at 0x11658d550>,
#   <matplotlib.axis.XTick at 0x11658dac8>,
#   <matplotlib.axis.XTick at 0x11658da20>,
#   <matplotlib.axis.XTick at 0x1165859b0>,
#   <matplotlib.axis.XTick at 0x11655f710>,
#   <matplotlib.axis.XTick at 0x116592518>,
#   <matplotlib.axis.XTick at 0x116592a90>,
#   <matplotlib.axis.XTick at 0x11659a0b8>,
#   <matplotlib.axis.XTick at 0x11659a588>,
#   <matplotlib.axis.XTick at 0x11659ab00>,
#   <matplotlib.axis.XTick at 0x1165a5128>,
#   <matplotlib.axis.XTick at 0x1165a5630>,
#   <matplotlib.axis.XTick at 0x11659a400>,
#   <matplotlib.axis.XTick at 0x11657ee80>,
#   <matplotlib.axis.XTick at 0x1165a59e8>,
#   <matplotlib.axis.XTick at 0x1165a5e48>,
#   <matplotlib.axis.XTick at 0x1165a8518>,
#   <matplotlib.axis.XTick at 0x1165a8ac8>,
#   <matplotlib.axis.XTick at 0x1165b20f0>,
#   <matplotlib.axis.XTick at 0x1165b2630>,
#   <matplotlib.axis.XTick at 0x1165b2ba8>,
#   <matplotlib.axis.XTick at 0x1165b2c88>,
#   <matplotlib.axis.XTick at 0x1165a8470>,
#   <matplotlib.axis.XTick at 0x1165925f8>,
#   <matplotlib.axis.XTick at 0x11654a278>,
#   <matplotlib.axis.XTick at 0x1165b6278>,
#   <matplotlib.axis.XTick at 0x1165b6780>,
#   <matplotlib.axis.XTick at 0x1165b6cf8>,
#   <matplotlib.axis.XTick at 0x1165bd2b0>,
#   <matplotlib.axis.XTick at 0x1165bd828>,
#   <matplotlib.axis.XTick at 0x1165bdd68>,
#   <matplotlib.axis.XTick at 0x1165bd8d0>,
#   <matplotlib.axis.XTick at 0x11655f7f0>,
#   <matplotlib.axis.XTick at 0x1165c3208>,
#   <matplotlib.axis.XTick at 0x1165c3780>,
#   <matplotlib.axis.XTick at 0x1165c3c88>,
#   <matplotlib.axis.XTick at 0x1165c81d0>,
#   <matplotlib.axis.XTick at 0x1165c8710>,
#   <matplotlib.axis.XTick at 0x1165c8c50>,
#   <matplotlib.axis.XTick at 0x1165d0240>,
#   <matplotlib.axis.XTick at 0x1165c8278>,
#   <matplotlib.axis.XTick at 0x1165c3080>,
#   <matplotlib.axis.XTick at 0x1165d05f8>,
#   <matplotlib.axis.XTick at 0x1165d0b70>,
#   <matplotlib.axis.XTick at 0x1165d5128>,
#   <matplotlib.axis.XTick at 0x1165d55c0>,
#   <matplotlib.axis.XTick at 0x1165d5b00>,
#   <matplotlib.axis.XTick at 0x1165da0b8>,
#   <matplotlib.axis.XTick at 0x1165da588>,
#   <matplotlib.axis.XTick at 0x1165d5fd0>,
#   <matplotlib.axis.XTick at 0x1165d04e0>,
#   <matplotlib.axis.XTick at 0x1165da630>,
#   <matplotlib.axis.XTick at 0x1165dadd8>,
#   <matplotlib.axis.XTick at 0x1165e2400>,
#   <matplotlib.axis.XTick at 0x1165e29e8>,
#   <matplotlib.axis.XTick at 0x1165e2f60>,
#   <matplotlib.axis.XTick at 0x1165e8518>,
#   <matplotlib.axis.XTick at 0x1165e8a58>,
#   <matplotlib.axis.XTick at 0x1165e8e48>,
#   <matplotlib.axis.XTick at 0x1165e2b38>,
#   <matplotlib.axis.XTick at 0x1165daa20>,
#   <matplotlib.axis.XTick at 0x1165ee438>,
#   <matplotlib.axis.XTick at 0x1165ee940>,
#   <matplotlib.axis.XTick at 0x1165eee80>,
#   <matplotlib.axis.XTick at 0x1165f4400>,
#   <matplotlib.axis.XTick at 0x1165f4908>],
#  <a list of 276 Text xticklabel objects>)

# %%
plt.show()

# %%
# help(sns.lmplot)

# %%
# fig, ax = plt.subplots(1,1, figsize=(6,6))
# N = 1000
# tag = np.random.randint(0,N,1000)
# # define the colormap
# cmap = plt.cm.jet

# scat = ax.scatter(over_1000.values(),over_1000.keys(),c=tag,s=np.random.randint(100,500,N),cmap=cmap,norm=norm)
# # create the colorbar
# cb = plt.colorbar(scat, spacing='proportional',ticks=bounds)
# cb.set_label('Custom cbar')
# ax.set_title('Discrete color mappings')
# plt.show()

# %%
sorted(over_1000.items())
# Out:
# [('God', 3709),
#  ('Jesus', 897),
#  ('Lord', 980),
#  ('a', 7892),
#  ('aaron', 313),
#  ('about', 566),
#  ('according', 766),
#  ('after', 1128),
#  ('again', 626),
#  ('against', 1606),
#  ('all', 5452),
#  ('also', 1687),
#  ('altar', 338),
#  ('am', 823),
#  ('among', 881),
#  ('an', 1651),
#  ('another', 413),
#  ('answered', 445),
#  ('any', 881),
#  ('are', 2829),
#  ('art', 479),
#  ('as', 3385),
#  ('at', 1501),
#  ('away', 816),
#  ('be', 6776),
#  ('because', 1169),
#  ('been', 310),
#  ('before', 1735),
#  ('behold', 1281),
#  ('blood', 419),
#  ('both', 348),
#  ('bread', 330),
#  ('brethren', 530),
#  ('bring', 705),
#  ('brother', 346),
#  ('brought', 834),
#  ('burnt', 347),
#  ('but', 3865),
#  ('by', 2522),
#  ('called', 597),
#  ('came', 2012),
#  ('cast', 483),
#  ('cause', 308),
#  ('children', 1733),
#  ('christ', 518),
#  ('cities', 421),
#  ('city', 791),
#  ('come', 1891),
#  ('commanded', 422),
#  ('congregation', 325),
#  ('cut', 307),
#  ('daughter', 314),
#  ('david', 973),
#  ('day', 1597),
#  ('days', 767),
#  ('dead', 332),
#  ('death', 317),
#  ('did', 970),
#  ('do', 1291),
#  ('done', 533),
#  ('down', 1028),
#  ('drink', 340),
#  ('dwell', 322),
#  ('earth', 827),
#  ('eat', 607),
#  ('egypt', 537),
#  ('even', 1347),
#  ('ever', 373),
#  ('every', 1182),
#  ('evil', 565),
#  ('eyes', 451),
#  ('face', 381),
#  ('father', 918),
#  ('fathers', 490),
#  ('fear', 370),
#  ('fire', 483),
#  ('first', 413),
#  ('five', 335),
#  ('flesh', 381),
#  ('for', 8673),
#  ('forth', 825),
#  ('found', 380),
#  ('four', 316),
#  ('gave', 446),
#  ('give', 860),
#  ('given', 475),
#  ('glory', 373),
#  ('go', 1421),
#  ('god', 321),
#  ('gold', 382),
#  ('good', 661),
#  ('great', 897),
#  ('had', 1937),
#  ('hand', 1311),
#  ('hands', 419),
#  ('hast', 1031),
#  ('hath', 2161),
#  ('have', 3747),
#  ('he', 10010),
#  ('head', 333),
#  ('hear', 515),
#  ('heard', 607),
#  ('heart', 775),
#  ('heaven', 527),
#  ('her', 1892),
#  ('high', 388),
#  ('him', 6025),
#  ('himself', 481),
#  ('his', 8158),
#  ('holy', 572),
#  ('house', 1867),
#  ('how', 516),
#  ('hundred', 564),
#  ('i', 8497),
#  ('if', 1542),
#  ('into', 1924),
#  ('israel', 2334),
#  ('it', 5673),
#  ('jacob', 338),
#  ('jerusalem', 695),
#  ('judah', 760),
#  ('keep', 356),
#  ('king', 2170),
#  ('kingdom', 320),
#  ('kings', 307),
#  ('know', 729),
#  ('land', 1597),
#  ('law', 488),
#  ('left', 326),
#  ('let', 1444),
#  ('life', 389),
#  ('like', 630),
#  ('lord', 6308),
#  ('love', 306),
#  ('made', 1346),
#  ('make', 1023),
#  ('man', 2455),
#  ('many', 524),
#  ('may', 990),
#  ('me', 3626),
#  ('men', 1536),
#  ('midst', 341),
#  ('might', 455),
#  ('mine', 609),
#  ('more', 637),
#  ('moses', 810),
#  ('mouth', 377),
#  ('my', 4156),
#  ('name', 852),
#  ('nations', 312),
#  ('neither', 843),
#  ('no', 1323),
#  ('none', 342),
#  ('nor', 737),
#  ('not', 6199),
#  ('now', 1286),
#  ('o', 1065),
#  ('of', 33340),
#  ('off', 467),
#  ('offering', 632),
#  ('old', 356),
#  ('one', 1887),
#  ('or', 1069),
#  ('other', 443),
#  ('our', 1123),
#  ('out', 2638),
#  ('over', 972),
#  ('own', 559),
#  ('pass', 804),
#  ('peace', 397),
#  ('people', 1979),
#  ('place', 641),
#  ('pray', 304),
#  ('priest', 467),
#  ('priests', 361),
#  ('put', 883),
#  ('right', 343),
#  ('round', 309),
#  ('said', 3837),
#  ('saith', 1206),
#  ('same', 311),
#  ('saul', 373),
#  ('saw', 527),
#  ('say', 1028),
#  ('saying', 1413),
#  ('sea', 358),
#  ('see', 567),
#  ('sent', 665),
#  ('servant', 449),
#  ('servants', 446),
#  ('set', 660),
#  ('seven', 443),
#  ('shall', 9565),
#  ('shalt', 1589),
#  ('she', 956),
#  ('should', 732),
#  ('side', 410),
#  ('sight', 303),
#  ('sin', 417),
#  ('so', 1618),
#  ('son', 2276),
#  ('sons', 1018),
#  ('soul', 416),
#  ('spake', 573),
#  ('speak', 481),
#  ('spirit', 467),
#  ('stood', 323),
#  ('sword', 376),
#  ('tabernacle', 311),
#  ('take', 847),
#  ('taken', 307),
#  ('than', 453),
#  ('that', 12452),
#  ('thee', 3434),
#  ('their', 3772),
#  ('them', 5840),
#  ('themselves', 371),
#  ('there', 2151),
#  ('therefore', 1201),
#  ('thereof', 784),
#  ('these', 1177),
#  ('they', 7081),
#  ('thine', 886),
#  ('thing', 495),
#  ('things', 1072),
#  ('this', 2646),
#  ('those', 445),
#  ('thou', 5276),
#  ('thousand', 495),
#  ('three', 452),
#  ('through', 447),
#  ('thus', 713),
#  ('thy', 4506),
#  ('time', 584),
#  ('to', 13067),
#  ('together', 425),
#  ('took', 738),
#  ('toward', 338),
#  ('two', 805),
#  ('under', 377),
#  ('until', 355),
#  ('unto', 8693),
#  ('up', 2221),
#  ('upon', 2625),
#  ('us', 1324),
#  ('voice', 465),
#  ('was', 4309),
#  ('water', 343),
#  ('way', 618),
#  ('we', 1801),
#  ('went', 1343),
#  ('were', 2664),
#  ('what', 925),
#  ('when', 2726),
#  ('where', 379),
#  ('wherefore', 338),
#  ('which', 4251),
#  ('who', 918),
#  ('whom', 735),
#  ('wicked', 308),
#  ('wife', 362),
#  ('will', 3687),
#  ('with', 5744),
#  ('without', 397),
#  ('woman', 338),
#  ('word', 655),
#  ('words', 485),
#  ('work', 383),
#  ('would', 412),
#  ('ye', 3864),
#  ('yea', 312),
#  ('year', 343),
#  ('years', 498),
#  ('yet', 645),
#  ('you', 2378),
#  ('your', 1714)]

# %%
# !pip3 install --upgrade bokeh
df_plot = pd.DataFrame(columns=["X", "Y"])
x = list(over_1000.keys())
y = list(over_1000.values())
df_plot['X'] = x
df_plot['Y'] = y
# sns.lmplot('X', 'Y',data=df_plot, fit_reg=False)

# %%
df_plot.head(4)
# Out:
#         X     Y
# 0     God  3709
# 1  heaven   527
# 2   earth   827
# 3     was  4309

# %%
"""
Simple demo of a scatter plot.
"""
import numpy as np
import matplotlib.pyplot as plt


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
from bokeh.models import HoverTool, ColumnDataSource,LogColorMapper
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
plt.figure(figsize=(10, 8))

# %%
# from scipy.stats import kendalltau
x = list(over_1000.keys())
y = list(over_1000.values())
df_bokeh = pd.DataFrame(columns=["X", "Y"])
df_bokeh["X"] = x
print(len(x))
df_bokeh["Y"] = y
print(len(y))
N = 4000
colors=["#084594"]
radii = np.random.random(size=N)
# Out:
# 276
# 276

# %%
# sns.pairplot(over_1000,x_vars=x, y_vars=y)
# output_file("rhema.html", title="Word Frequency")
p = figure()
p.circle(df_bokeh["X"],df_bokeh["Y"], radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
# Out:
# /usr/local/lib/python3.6/site-packages/bokeh/models/sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('radius', 4000), ('x', 276)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /usr/local/lib/python3.6/site-packages/bokeh/models/sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('radius', 4000), ('x', 276), ('y', 276)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /usr/local/lib/python3.6/site-packages/bokeh/models/sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('fill_color', 1), ('radius', 4000), ('x', 276), ('y', 276)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# GlyphRenderer(id='917363c5-1644-4d55-a13a-62f4af96c77c', ...)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1f06962b-4580-4945-a086-080b237d8255">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7293070c-78ce-43af-94d3-fd3f8018da06"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7293070c-78ce-43af-94d3-fd3f8018da06");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7293070c-78ce-43af-94d3-fd3f8018da06");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7293070c-78ce-43af-94d3-fd3f8018da06' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"05c00d44-0859-4fb7-bd3f-48bb6a69e453":{"roots":{"references":[{"attributes":{"below":[{"id":"0c98d9c1-8e69-462f-932a-9746aa86ca17","type":"LinearAxis"}],"left":[{"id":"a6a10f16-06bb-4a55-abf2-871c90db6ee1","type":"LinearAxis"}],"renderers":[{"id":"0c98d9c1-8e69-462f-932a-9746aa86ca17","type":"LinearAxis"},{"id":"bc2bc280-c6db-4b3c-9e17-c05bdd16d9cc","type":"Grid"},{"id":"a6a10f16-06bb-4a55-abf2-871c90db6ee1","type":"LinearAxis"},{"id":"b9385659-2d3b-4243-896a-65586b387b0f","type":"Grid"},{"id":"214f6215-084d-4948-8be6-7d43eab476ca","type":"BoxAnnotation"},{"id":"917363c5-1644-4d55-a13a-62f4af96c77c","type":"GlyphRenderer"}],"title":{"id":"e1f9ea6e-419c-4155-9cf7-c3a3fa243323","type":"Title"},"tool_events":{"id":"8dc8ccde-a84d-43e8-8169-33ff9a923fab","type":"ToolEvents"},"toolbar":{"id":"ed797e86-3a05-40b5-8c5a-5ea320f806df","type":"Toolbar"},"x_range":{"id":"6dbc0162-7808-4c83-b31e-a48497a9d5d2","type":"DataRange1d"},"x_scale":{"id":"a6f3f19e-89e2-4412-906b-5c5be2755e33","type":"LinearScale"},"y_range":{"id":"9116cb4e-a514-4d28-af49-dc65d052052c","type":"DataRange1d"},"y_scale":{"id":"d74c1afb-0995-4953-8d45-030ca463411b","type":"LinearScale"}},"id":"e4369c4e-9a93-4d20-b798-8fed569ad9e7","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"e4369c4e-9a93-4d20-b798-8fed569ad9e7","subtype":"Figure","type":"Plot"}},"id":"a9402435-216c-42d3-af59-9eff69f813c1","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["radius","x","y","fill_color"],"data":{"fill_color":["#084594"],"radius":{"__ndarray__":"...","dtype":"float64","shape":[4000]},"x":["God","heaven","earth","was","without","upon","face","of","spirit","said","let","there","be","saw","that","it","called","day","he","were","first","a","midst","made","which","under","so","together","unto","one","place","land","good","bring","forth","after","his","brought","to","them","for","days","give","two","great","also","set","over","hath","life","may","every","their","saying","thing","us","make","man","our","have","sea","all","own","him","behold","i","given","you","shall","had","thus","work","because","these","are","when","they","lord","before","not","but","went","up","into","soul","put","whom","out","sight","evil","water","four","name","where","gold","same","toward","took","keep","commanded","thou","shalt","eat","thereof","should","will","an","see","what","would","gave","found","flesh","taken","woman","her","this","now","my","she","therefore","father","both","wife","more","than","any","yea","ye","we","neither","know","your","eyes","as","did","with","themselves","heard","voice","art","thy","who","thee","hast","me","done","go","head","children","bread","hand","take","sent","at","sword","way","again","brother","time","came","pass","offering","if","sin","against","am","blood","mouth","come","city","son","other","dwell","hear","another","men","hundred","years","sons","five","seven","three","hands","yet","those","old","heart","through","side","even","do","according","house","by","cause","off","year","high","things","until","no","spake","altar","burnt","fear","cut","brethren","servant","servants","nations","wherefore","kingdom","down","people","left","daughter","law","egypt","say","pray","might","away","been","right","or","like","cities","wicked","thine","ever","king","kings","himself","priest","mine","word","fathers","peace","many","among","o","stood","answered","speak","round","fire","drink","nor","dead","thousand","cast","death","saith","none","about","words","jacob","how","love","judah","glory","israel","saul","priests","moses","holy","aaron","god","congregation","tabernacle","Lord","jerusalem","david","Jesus","christ"],"y":[3709,527,827,4309,397,2625,381,33340,467,3837,1444,2151,6776,527,12452,5673,597,1597,10010,2664,413,7892,341,1346,4251,377,1618,425,8693,1887,641,1597,661,705,825,1128,8158,834,13067,5840,8673,767,860,805,897,1687,660,972,2161,389,990,1182,3772,1413,495,1324,1023,2455,1123,3747,358,5452,559,6025,1281,8497,475,2378, ...

# %%
 p = figure(title="Rhema Word Freq", x_axis_label='Word', y_axis_label='Freq')

# %%
p.line(x,y, legend="Worded", line_width=2)
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="304568ba-989c-49f1-b7a0-e9664698d780">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa033833-6c25-4c40-b243-1159b611f175"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fa033833-6c25-4c40-b243-1159b611f175");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa033833-6c25-4c40-b243-1159b611f175");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa033833-6c25-4c40-b243-1159b611f175' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9ff0ab0e-55ea-4ec3-8b2a-f017e1baf927":{"roots":{"references":[{"attributes":{},"id":"10005b82-4b59-48e9-8ee0-ccf9a4a5b2a3","type":"BasicTickFormatter"},{"attributes":{"items":[{"id":"ad818a0b-97fa-4b70-80a8-c6ec3381710c","type":"LegendItem"}],"plot":{"id":"86b3678c-43e1-4629-8c1d-931eea880c78","subtype":"Figure","type":"Plot"}},"id":"57e5cb2e-482a-4f13-b884-efd99a18040c","type":"Legend"},{"attributes":{"plot":null,"text":"Rhema Word Freq"},"id":"27cf1b42-0087-4e56-9fbb-28b43fab772c","type":"Title"},{"attributes":{"axis_label":"Freq","formatter":{"id":"ae45940f-2489-4f65-a312-2c55dccdbe4f","type":"BasicTickFormatter"},"plot":{"id":"86b3678c-43e1-4629-8c1d-931eea880c78","subtype":"Figure","type":"Plot"},"ticker":{"id":"09b482de-4ca1-487b-9ee7-1d9f00feaaf7","type":"BasicTicker"}},"id":"ee5d2e01-6b0b-43b1-88a5-3b9a28ae4886","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"840792cc-4893-483f-bd9d-3094a6179308","type":"Line"},{"attributes":{"plot":{"id":"86b3678c-43e1-4629-8c1d-931eea880c78","subtype":"Figure","type":"Plot"},"ticker":{"id":"d62de4de-3076-4880-b51c-9a97167b36b2","type":"BasicTicker"}},"id":"faa7bb7a-8fb4-4aed-a3ae-9250044f0308","type":"Grid"},{"attributes":{"plot":{"id":"86b3678c-43e1-4629-8c1d-931eea880c78","subtype":"Figure","type":"Plot"}},"id":"4cdbf553-fbc4-4a00-b7cd-efe83aa3c04a","type":"PanTool"},{"attributes":{"axis_label":"Word","formatter":{"id":"10005b82-4b59-48e9-8ee0-ccf9a4a5b2a3","type":"BasicTickFormatter"},"plot":{"id":"86b3678c-43e1-4629-8c1d-931eea880c78","subtype":"Figure","type":"Plot"},"ticker":{"id":"d62de4de-3076-4880-b51c-9a97167b36b2","type":"BasicTicker"}},"id":"68995110-aeca-44e5-806f-4aafe900dbbc","type":"LinearAxis"},{"attributes":{"below":[{"id":"68995110-aeca-44e5-806f-4aafe900dbbc","type":"LinearAxis"}],"left":[{"id":"ee5d2e01-6b0b-43b1-88a5-3b9a28ae4886","type":"LinearAxis"}],"renderers":[{"id":"68995110-aeca-44e5-806f-4aafe900dbbc","type":"LinearAxis"},{"id":"faa7bb7a-8fb4-4aed-a3ae-9250044f0308","type":"Grid"},{"id":"ee5d2e01-6b0b-43b1-88a5-3b9a28ae4886","type":"LinearAxis"},{"id":"55500a50-d22a-4809-ae23-e299f7302a29","type":"Grid"},{"id":"d3245df4-d420-43e7-b535-771a3353e13b","type":"BoxAnnotation"},{"id":"57e5cb2e-482a-4f13-b884-efd99a18040c","type":"Legend"},{"id":"13640518-5d96-48bf-a362-f6b85cc5e84f","type":"GlyphRenderer"}],"title":{"id":"27cf1b42-0087-4e56-9fbb-28b43fab772c","type":"Title"},"tool_events":{"id":"fb4a9188-5205-4f13-8b09-18054ea237db","type":"ToolEvents"},"toolbar":{"id":"d1919575-eb9e-45cc-bb09-170235b42d3d","type":"Toolbar"},"x_range":{"id":"b7059d35-7ab6-47eb-b58e-ebc1dd3efc2b","type":"DataRange1d"},"x_scale":{"id":"5869442b-8fb0-4c51-9b38-497be92d2ed7","type":"LinearScale"},"y_range":{"id":"2adbd60d-0d8b-443a-8b40-64f26f00bce6","type":"DataRange1d"},"y_scale":{"id":"08e13b21-6121-49cb-8bea-7c5502e22f2c","type":"LinearScale"}},"id":"86b3678c-43e1-4629-8c1d-931eea880c78","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d62de4de-3076-4880-b51c-9a97167b36b2","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d3245df4-d420-43e7-b535-771a3353e13b","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":["God","heaven","earth","was","without","upon","face","of","spirit","said","let","there","be","saw","that","it","called","day","he","were","first","a","midst","made","which","under","so","together","unto","one","place","land","good","bring","forth","after","his","brought","to","them","for","days","give","two","great","also","set","over","hath","life","may","every","their","saying","thing", ...

# %%
plt.figure(figsize=(14, 10))
sns.distplot(df_bokeh["Y"], bins=20, kde=False, rug=True);
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# sns.jointplot(x="x", y="y", data=df_bokeh);

# %%
plt.figure(figsize=(12, 10))
sns.swarmplot(x=df_bokeh["X"], y=df_bokeh["Y"], data=df_bokeh);

# %%
sns.distplot(df_bokeh["Y"], kde=False, rug=True);
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set()

# Load the example flights dataset and conver to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5)

# %%
sns.pairplot(df_bokeh);

# %%
import seaborn as sns; 
sns.set(style="ticks", color_codes=True)
tips = df_bokeh
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-c4853dcf4403> in <module>()
#       2 sns.set(style="ticks", color_codes=True)
#       3 tips = df_bokeh
# ----> 4 g = sns.JointGrid(x="total_bill", y="tip", data=tips)
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1681             if isinstance(var, string_types):
#    1682                 err = "Could not interpret input '{}'".format(var)
# -> 1683                 raise ValueError(err)
#    1684
#    1685         # Possibly drop NA
#
# ValueError: Could not interpret input 'total_bill'

# %%
# g = sns.JointGrid(x="total_bill", y="tip", data=tips)
# g = g.plot(sns.regplot, sns.distplot)

# %%
sns.distplot(df_bokeh["Y"]);

# %%
sns.kdeplot(df_bokeh["Y"], shade=True);

# %%
# df = pd.DataFrame(over_1000)
# df = pd.DataFrame.from_dict(over_1000, orient='columns', dtype=None)
# plt.plot.area()
# sns.lmplot('x', 'y', data=df_verses, fit_reg=False)

# %%
# data = pd.read_fwf('data.txt', header = None)
data = pd.read_fwf('data.txt', names=['Books','Verse','Extras'])

len(data)

# %%
df_data = pd.DataFrame(data)

# %%
df_data.head()
df_heads = df_data['Books']
# books = df_data.groupby[df_data['0']]

# %%
df_heads.head()
