# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import sys
import os
# !head -n 3 data.txt
# Out:
# Genesis 1:1	In the beginning God created the heaven and the earth.
# Genesis 1:2	And the earth was without form, and void; and darkness was upon the face of the deep. And the Spirit of God moved upon the face of the waters.
# Genesis 1:3	And God said, Let there be light: and there was light.

# %%
data_col=['book_bible','verse', 'extra']

# %%
df_text = pd.read_fwf('data.txt', sep=" ", colspecs='infer', names=data_col, widths=None, squeeze=True, header=None)
# df_text = pd.read_fwf('data.txt',colspecs='infer')

# %%
df_text.describe()
# Out:
#        book_bible                        verse extra
# count       31102                        31102  1076
# unique        311                        31090   845
# top        Psalms  Then Job answered and said,     .
# freq         2461                            4    29

# %%
df_text.head(3)
# Out:
#   book_bible                                              verse extra
# 0    Genesis  1:1\tIn the beginning God created the heaven a...   NaN
# 1    Genesis  1:2\tAnd the earth was without form, and void;...   NaN
# 2    Genesis  1:3\tAnd God said, Let there be light: and the...   NaN

# %%
df_text.tail(3)
# Out:
#       book_bible                                              verse extra
# 31099    Revelat  on 22:19\tAnd if any man shall take away from ...   NaN
# 31100    Revelat  on 22:20\tHe which testifieth these things sai...   NaN
# 31101    Revelat  on 22:21\tThe grace of our Lord Jesus Christ b...   NaN

# %%
del df_text['extra']

# %%
books_old_testament = ["Genesis","Exodus","Leviticus","Numbers","Deuteronomy","Joshua","Judges","Ruth","1 Samuel",
                       "2 Samuel","1 Kings","2 Kings","1 Chronicles","2 Chronicles","Ezra","Nehemiah","Esther","Job",
                       "Psalms","Proverbs","Ecclesiastes","Song of Solomon","Isaiah","Jeremiah","Lamentations","Ezekiel",
                       "Daniel","Hosea","Joel","Amos","Obadiah","Jonah","Micah","Nahum","Habakkuk","Zephaniah","Haggai",
                       "Zechariah","Malachi"]

# %%
books_new_testament = ["Matthew","Mark","Luke","John","Acts of Apostles","Romans","1 Corinthians","2 Corinthians",
                      "Galatians","Ephesians","Philippians","Colossians","1 Thessalonians","2 Thessalonians","1 Timothy",
                      "2 Timothy","Titus","Philemon","Hebrews","James","1 Peter","2 Peter","1 John","2 John","3 John",
                      "Jude","Revelation"]

# %%
df_text.columns
# Out:
# Index(['book_bible', 'verse'], dtype='object')

# %%
df_verses = df_text['verse']

# %%
df_verses.head(3)
# Out:
# 0    1:1\tIn the beginning God created the heaven a...
# 1    1:2\tAnd the earth was without form, and void;...
# 2    1:3\tAnd God said, Let there be light: and the...
# Name: verse, dtype: object

# %%
for row in df_verses:
    print(row)
    break
# Out:
# 1:1	In the beginning God created the heaven and the earth.

# %%
# global _counted
# _counted = {}
# count = 0

# %%
_counted = {}
count = 0

for row in df_verses:
    stringed = str(row)
#     Clean each line - Remove punctuations
    pos = stringed.find('\t')
    stringed = stringed[pos:]
#     print(stringed)

    stringed = stringed.replace(",","")
    stringed = stringed.replace(";","")
    stringed = stringed.replace(".","")
    stringed = stringed.replace("?","")
    stringed = stringed.replace("!","")
    stringed = stringed.replace("(","")
    stringed = stringed.replace(")","")
#     stringed = stringed.replace("\t"," ")
    stringed = stringed.strip()
    collects = list(stringed.split(" "))

    for item in collects:
        if '\t' in item:
            item = item.replace('\t',' ')
        if item not in ['God','Jesus', 'Lord']:
            item = item.lower()
            
        if ":" in item:
            continue
        
        if item == '':
            continue
            
        try:
            _counted[item] = _counted[item] + 1
        except KeyError:
            _counted[item] = 1

# %%
# sorted(_counted)
over_1000 = {}

for key in _counted.keys():
    if _counted[key] > 300:
        over_1000['{}'.format(key)] = _counted[key]
        

print(len(over_1000))
# Out:
# 283

# %%
# sorted(_counted.values())
plt.bar(range(len(over_1000)), over_1000.values(), align="center", color="g")
plt.xticks(range(len(over_1000)), list(over_1000.keys()))
# Out:
# ([<matplotlib.axis.XTick at 0x10ac238d0>,
#   <matplotlib.axis.XTick at 0x10afa7748>,
#   <matplotlib.axis.XTick at 0x10afa1cc0>,
#   <matplotlib.axis.XTick at 0x10b5db9b0>,
#   <matplotlib.axis.XTick at 0x10b5df550>,
#   <matplotlib.axis.XTick at 0x10b5e50b8>,
#   <matplotlib.axis.XTick at 0x10b5e5c18>,
#   <matplotlib.axis.XTick at 0x10b5eb7f0>,
#   <matplotlib.axis.XTick at 0x10b5f1358>,
#   <matplotlib.axis.XTick at 0x10b5f1eb8>,
#   <matplotlib.axis.XTick at 0x10b5faa58>,
#   <matplotlib.axis.XTick at 0x10b5fe5f8>,
#   <matplotlib.axis.XTick at 0x10b604160>,
#   <matplotlib.axis.XTick at 0x10b604cc0>,
#   <matplotlib.axis.XTick at 0x10b607828>,
#   <matplotlib.axis.XTick at 0x10b60c3c8>,
#   <matplotlib.axis.XTick at 0x10b60cef0>,
#   <matplotlib.axis.XTick at 0x10b616a90>,
#   <matplotlib.axis.XTick at 0x10b61a5f8>,
#   <matplotlib.axis.XTick at 0x10b61f198>,
#   <matplotlib.axis.XTick at 0x10b61fcc0>,
#   <matplotlib.axis.XTick at 0x10b629828>,
#   <matplotlib.axis.XTick at 0x10b62b400>,
#   <matplotlib.axis.XTick at 0x10b62bf28>,
#   <matplotlib.axis.XTick at 0x10b62eac8>,
#   <matplotlib.axis.XTick at 0x10b635668>,
#   <matplotlib.axis.XTick at 0x10b63b208>,
#   <matplotlib.axis.XTick at 0x10b63bd68>,
#   <matplotlib.axis.XTick at 0x10b63f898>,
#   <matplotlib.axis.XTick at 0x10b653438>,
#   <matplotlib.axis.XTick at 0x10b653f60>,
#   <matplotlib.axis.XTick at 0x10b67bac8>,
#   <matplotlib.axis.XTick at 0x10b6c1630>,
#   <matplotlib.axis.XTick at 0x10b6cc198>,
#   <matplotlib.axis.XTick at 0x10b6cccf8>,
#   <matplotlib.axis.XTick at 0x10b6d9860>,
#   <matplotlib.axis.XTick at 0x10b6e3390>,
#   <matplotlib.axis.XTick at 0x10b6e3eb8>,
#   <matplotlib.axis.XTick at 0x10b6e6a20>,
#   <matplotlib.axis.XTick at 0x10b6f45c0>,
#   <matplotlib.axis.XTick at 0x10b6f80f0>,
#   <matplotlib.axis.XTick at 0x10b6f8c18>,
#   <matplotlib.axis.XTick at 0x10b701780>,
#   <matplotlib.axis.XTick at 0x10b7082e8>,
#   <matplotlib.axis.XTick at 0x10b708e48>,
#   <matplotlib.axis.XTick at 0x10b70c9e8>,
#   <matplotlib.axis.XTick at 0x10b723550>,
#   <matplotlib.axis.XTick at 0x10b7260b8>,
#   <matplotlib.axis.XTick at 0x10b726c18>,
#   <matplotlib.axis.XTick at 0x10b7297f0>,
#   <matplotlib.axis.XTick at 0x10b72f358>,
#   <matplotlib.axis.XTick at 0x10b72fe80>,
#   <matplotlib.axis.XTick at 0x10b7369b0>,
#   <matplotlib.axis.XTick at 0x10b7405c0>,
#   <matplotlib.axis.XTick at 0x10b744160>,
#   <matplotlib.axis.XTick at 0x10b744c88>,
#   <matplotlib.axis.XTick at 0x10b7507f0>,
#   <matplotlib.axis.XTick at 0x10b756390>,
#   <matplotlib.axis.XTick at 0x10b756e80>,
#   <matplotlib.axis.XTick at 0x10b75ca20>,
#   <matplotlib.axis.XTick at 0x10ac116d8>,
#   <matplotlib.axis.XTick at 0x10bf7e198>,
#   <matplotlib.axis.XTick at 0x10bf7ec88>,
#   <matplotlib.axis.XTick at 0x10bf827b8>,
#   <matplotlib.axis.XTick at 0x10bf872e8>,
#   <matplotlib.axis.XTick at 0x10bf87dd8>,
#   <matplotlib.axis.XTick at 0x10bf8b908>,
#   <matplotlib.axis.XTick at 0x10bf8e438>,
#   <matplotlib.axis.XTick at 0x10bf8ef28>,
#   <matplotlib.axis.XTick at 0x10bf93a58>,
#   <matplotlib.axis.XTick at 0x10bf96588>,
#   <matplotlib.axis.XTick at 0x10bf9a0b8>,
#   <matplotlib.axis.XTick at 0x10bf9aba8>,
#   <matplotlib.axis.XTick at 0x10bf9c6d8>,
#   <matplotlib.axis.XTick at 0x10bfa1208>,
#   <matplotlib.axis.XTick at 0x10bfa1cf8>,
#   <matplotlib.axis.XTick at 0x10bfa4828>,
#   <matplotlib.axis.XTick at 0x10bfa8358>,
#   <matplotlib.axis.XTick at 0x10bfa8e48>,
#   <matplotlib.axis.XTick at 0x10bfad978>,
#   <matplotlib.axis.XTick at 0x10bfb04a8>,
#   <matplotlib.axis.XTick at 0x10bfb0f98>,
#   <matplotlib.axis.XTick at 0x10bfb3ac8>,
#   <matplotlib.axis.XTick at 0x10bfb75f8>,
#   <matplotlib.axis.XTick at 0x10bfbd128>,
#   <matplotlib.axis.XTick at 0x10bfbdc18>,
#   <matplotlib.axis.XTick at 0x10bfbf748>,
#   <matplotlib.axis.XTick at 0x10bfc5278>,
#   <matplotlib.axis.XTick at 0x10bfc5d68>,
#   <matplotlib.axis.XTick at 0x10bfc8898>,
#   <matplotlib.axis.XTick at 0x10bfcb3c8>,
#   <matplotlib.axis.XTick at 0x10bfcbeb8>,
#   <matplotlib.axis.XTick at 0x10bfd19e8>,
#   <matplotlib.axis.XTick at 0x10bfd3518>,
#   <matplotlib.axis.XTick at 0x10bfd8048>,
#   <matplotlib.axis.XTick at 0x10bfd8b38>,
#   <matplotlib.axis.XTick at 0x10bfda668>,
#   <matplotlib.axis.XTick at 0x10bfdf198>,
#   <matplotlib.axis.XTick at 0x10bfdfc88>,
#   <matplotlib.axis.XTick at 0x10bfe27b8>,
#   <matplotlib.axis.XTick at 0x10bfe62e8>,
#   <matplotlib.axis.XTick at 0x10bfe6dd8>,
#   <matplotlib.axis.XTick at 0x10bfea908>,
#   <matplotlib.axis.XTick at 0x10bfee438>,
#   <matplotlib.axis.XTick at 0x10bfeef28>,
#   <matplotlib.axis.XTick at 0x10bff2a58>,
#   <matplotlib.axis.XTick at 0x10bff5588>,
#   <matplotlib.axis.XTick at 0x10bffa0b8>,
#   <matplotlib.axis.XTick at 0x10bffaba8>,
#   <matplotlib.axis.XTick at 0x10bffe6d8>,
#   <matplotlib.axis.XTick at 0x10c001208>,
#   <matplotlib.axis.XTick at 0x10c001cf8>,
#   <matplotlib.axis.XTick at 0x10c004828>,
#   <matplotlib.axis.XTick at 0x10c008358>,
#   <matplotlib.axis.XTick at 0x10c008e48>,
#   <matplotlib.axis.XTick at 0x10c00d978>,
#   <matplotlib.axis.XTick at 0x10c0104a8>,
#   <matplotlib.axis.XTick at 0x10c010f98>,
#   <matplotlib.axis.XTick at 0x10c015ac8>,
#   <matplotlib.axis.XTick at 0x10c0175f8>,
#   <matplotlib.axis.XTick at 0x10c01d128>,
#   <matplotlib.axis.XTick at 0x10c01dc18>,
#   <matplotlib.axis.XTick at 0x10c01f748>,
#   <matplotlib.axis.XTick at 0x10c023278>,
#   <matplotlib.axis.XTick at 0x10c023d68>,
#   <matplotlib.axis.XTick at 0x10c028898>,
#   <matplotlib.axis.XTick at 0x10c02c3c8>,
#   <matplotlib.axis.XTick at 0x10c02ceb8>,
#   <matplotlib.axis.XTick at 0x10c02f9e8>,
#   <matplotlib.axis.XTick at 0x10c033518>,
#   <matplotlib.axis.XTick at 0x10c038048>,
#   <matplotlib.axis.XTick at 0x10c038b38>,
#   <matplotlib.axis.XTick at 0x10c03c668>,
#   <matplotlib.axis.XTick at 0x10c03f198>,
#   <matplotlib.axis.XTick at 0x10c03fc88>,
#   <matplotlib.axis.XTick at 0x10c0417b8>,
#   <matplotlib.axis.XTick at 0x10c0472e8>,
#   <matplotlib.axis.XTick at 0x10c047dd8>,
#   <matplotlib.axis.XTick at 0x10c04b908>,
#   <matplotlib.axis.XTick at 0x10c04d438>,
#   <matplotlib.axis.XTick at 0x10c04df28>,
#   <matplotlib.axis.XTick at 0x10c052a58>,
#   <matplotlib.axis.XTick at 0x10c055588>,
#   <matplotlib.axis.XTick at 0x10c0590b8>,
#   <matplotlib.axis.XTick at 0x10c059ba8>,
#   <matplotlib.axis.XTick at 0x10c05c6d8>,
#   <matplotlib.axis.XTick at 0x10c060208>,
#   <matplotlib.axis.XTick at 0x10c060cf8>,
#   <matplotlib.axis.XTick at 0x10c065828>,
#   <matplotlib.axis.XTick at 0x10c069358>,
#   <matplotlib.axis.XTick at 0x10c069e48>,
#   <matplotlib.axis.XTick at 0x10c06d978>,
#   <matplotlib.axis.XTick at 0x10c0704a8>,
#   <matplotlib.axis.XTick at 0x10c070f98>,
#   <matplotlib.axis.XTick at 0x10c076ac8>,
#   <matplotlib.axis.XTick at 0x10c0785f8>,
#   <matplotlib.axis.XTick at 0x10c07c128>,
#   <matplotlib.axis.XTick at 0x10c07cc18>,
#   <matplotlib.axis.XTick at 0x10c07f748>,
#   <matplotlib.axis.XTick at 0x10c084278>,
#   <matplotlib.axis.XTick at 0x10c084d68>,
#   <matplotlib.axis.XTick at 0x10c088898>,
#   <matplotlib.axis.XTick at 0x10c08b3c8>,
#   <matplotlib.axis.XTick at 0x10c08beb8>,
#   <matplotlib.axis.XTick at 0x10c08f9e8>,
#   <matplotlib.axis.XTick at 0x10c093518>,
#   <matplotlib.axis.XTick at 0x10c096048>,
#   <matplotlib.axis.XTick at 0x10c096b38>,
#   <matplotlib.axis.XTick at 0x10c09a668>,
#   <matplotlib.axis.XTick at 0x10c09f198>,
#   <matplotlib.axis.XTick at 0x10c09fc88>,
#   <matplotlib.axis.XTick at 0x10c0a37b8>,
#   <matplotlib.axis.XTick at 0x10c0a62e8>,
#   <matplotlib.axis.XTick at 0x10c0a6dd8>,
#   <matplotlib.axis.XTick at 0x10c0aa908>,
#   <matplotlib.axis.XTick at 0x10c0ae438>,
#   <matplotlib.axis.XTick at 0x10c0aef28>,
#   <matplotlib.axis.XTick at 0x10c0b2a58>,
#   <matplotlib.axis.XTick at 0x10c0b5588>,
#   <matplotlib.axis.XTick at 0x10c0b90b8>,
#   <matplotlib.axis.XTick at 0x10c0b9ba8>,
#   <matplotlib.axis.XTick at 0x10c0bc6d8>,
#   <matplotlib.axis.XTick at 0x10c0c1208>,
#   <matplotlib.axis.XTick at 0x10c0c1cf8>,
#   <matplotlib.axis.XTick at 0x10c0c4828>,
#   <matplotlib.axis.XTick at 0x10c0c8358>,
#   <matplotlib.axis.XTick at 0x10c0c8e48>,
#   <matplotlib.axis.XTick at 0x10c0ce978>,
#   <matplotlib.axis.XTick at 0x10c0d04a8>,
#   <matplotlib.axis.XTick at 0x10c0d0f98>,
#   <matplotlib.axis.XTick at 0x10c0d4ac8>,
#   <matplotlib.axis.XTick at 0x10c0d85f8>,
#   <matplotlib.axis.XTick at 0x10c0dd128>,
#   <matplotlib.axis.XTick at 0x10c0ddc18>,
#   <matplotlib.axis.XTick at 0x10c0e0748>,
#   <matplotlib.axis.XTick at 0x10c0e4278>,
#   <matplotlib.axis.XTick at 0x10c0e4d68>,
#   <matplotlib.axis.XTick at 0x10c0e7898>,
#   <matplotlib.axis.XTick at 0x10c0eb3c8>,
#   <matplotlib.axis.XTick at 0x10c0ebeb8>,
#   <matplotlib.axis.XTick at 0x10c0f09e8>,
#   <matplotlib.axis.XTick at 0x10c0f2518>,
#   <matplotlib.axis.XTick at 0x10c0f7048>,
#   <matplotlib.axis.XTick at 0x10c0f7b38>,
#   <matplotlib.axis.XTick at 0x10c0fa668>,
#   <matplotlib.axis.XTick at 0x10c0fe198>,
#   <matplotlib.axis.XTick at 0x10c0fec88>,
#   <matplotlib.axis.XTick at 0x10c1027b8>,
#   <matplotlib.axis.XTick at 0x10c1052e8>,
#   <matplotlib.axis.XTick at 0x10c105dd8>,
#   <matplotlib.axis.XTick at 0x10c10b908>,
#   <matplotlib.axis.XTick at 0x10c10e438>,
#   <matplotlib.axis.XTick at 0x10c10ef28>,
#   <matplotlib.axis.XTick at 0x10c111a58>,
#   <matplotlib.axis.XTick at 0x10c114588>,
#   <matplotlib.axis.XTick at 0x10c11a0b8>,
#   <matplotlib.axis.XTick at 0x10c11aba8>,
#   <matplotlib.axis.XTick at 0x10c11d6d8>,
#   <matplotlib.axis.XTick at 0x10c121208>,
#   <matplotlib.axis.XTick at 0x10c121cf8>,
#   <matplotlib.axis.XTick at 0x10c124828>,
#   <matplotlib.axis.XTick at 0x10c129358>,
#   <matplotlib.axis.XTick at 0x10c129e48>,
#   <matplotlib.axis.XTick at 0x10c12d978>,
#   <matplotlib.axis.XTick at 0x10c1304a8>,
#   <matplotlib.axis.XTick at 0x10c130f98>,
#   <matplotlib.axis.XTick at 0x10c135ac8>,
#   <matplotlib.axis.XTick at 0x10c1375f8>,
#   <matplotlib.axis.XTick at 0x10c13c128>,
#   <matplotlib.axis.XTick at 0x10c13cc18>,
#   <matplotlib.axis.XTick at 0x10c13f748>,
#   <matplotlib.axis.XTick at 0x10c143278>,
#   <matplotlib.axis.XTick at 0x10c143d68>,
#   <matplotlib.axis.XTick at 0x10c149898>,
#   <matplotlib.axis.XTick at 0x10c14b3c8>,
#   <matplotlib.axis.XTick at 0x10c14beb8>,
#   <matplotlib.axis.XTick at 0x10c14f9e8>,
#   <matplotlib.axis.XTick at 0x10c153518>,
#   <matplotlib.axis.XTick at 0x10c157048>,
#   <matplotlib.axis.XTick at 0x10c157b38>,
#   <matplotlib.axis.XTick at 0x10c15b668>,
#   <matplotlib.axis.XTick at 0x10c15e198>,
#   <matplotlib.axis.XTick at 0x10c15ec88>,
#   <matplotlib.axis.XTick at 0x10c1617b8>,
#   <matplotlib.axis.XTick at 0x10c1662e8>,
#   <matplotlib.axis.XTick at 0x10c166dd8>,
#   <matplotlib.axis.XTick at 0x10c16a908>,
#   <matplotlib.axis.XTick at 0x10c16c438>,
#   <matplotlib.axis.XTick at 0x10c16cf28>,
#   <matplotlib.axis.XTick at 0x10c172a58>,
#   <matplotlib.axis.XTick at 0x10c174588>,
#   <matplotlib.axis.XTick at 0x10c1780b8>,
#   <matplotlib.axis.XTick at 0x10c178ba8>,
#   <matplotlib.axis.XTick at 0x10c17e6d8>,
#   <matplotlib.axis.XTick at 0x10c182208>,
#   <matplotlib.axis.XTick at 0x10c182cf8>,
#   <matplotlib.axis.XTick at 0x10c185828>,
#   <matplotlib.axis.XTick at 0x10c189358>,
#   <matplotlib.axis.XTick at 0x10c189e48>,
#   <matplotlib.axis.XTick at 0x10c18c978>,
#   <matplotlib.axis.XTick at 0x10c1904a8>,
#   <matplotlib.axis.XTick at 0x10c190f98>,
#   <matplotlib.axis.XTick at 0x10c195ac8>,
#   <matplotlib.axis.XTick at 0x10c1985f8>,
#   <matplotlib.axis.XTick at 0x10c19c128>,
#   <matplotlib.axis.XTick at 0x10c19cc18>,
#   <matplotlib.axis.XTick at 0x10c19f748>,
#   <matplotlib.axis.XTick at 0x10c1a3278>,
#   <matplotlib.axis.XTick at 0x10c1a3d68>,
#   <matplotlib.axis.XTick at 0x10c1a8898>,
#   <matplotlib.axis.XTick at 0x10c1aa3c8>,
#   <matplotlib.axis.XTick at 0x10c1aaeb8>,
#   <matplotlib.axis.XTick at 0x10c1af9e8>,
#   <matplotlib.axis.XTick at 0x10c1b3518>,
#   <matplotlib.axis.XTick at 0x10c1b7048>,
#   <matplotlib.axis.XTick at 0x10c1b7b38>,
#   <matplotlib.axis.XTick at 0x10c1bb668>,
#   <matplotlib.axis.XTick at 0x10c1bf198>,
#   <matplotlib.axis.XTick at 0x10c1bfc88>,
#   <matplotlib.axis.XTick at 0x10c1c27b8>,
#   <matplotlib.axis.XTick at 0x10c1c52e8>,
#   <matplotlib.axis.XTick at 0x10c1c5dd8>,
#   <matplotlib.axis.XTick at 0x10c1c9908>],
#  <a list of 283 Text xticklabel objects>)

# %%
plt.show()

# %%
# help(sns.lmplot)

# %%
# fig, ax = plt.subplots(1,1, figsize=(6,6))
# N = 1000
# tag = np.random.randint(0,N,1000)
# # define the colormap
# cmap = plt.cm.jet

# scat = ax.scatter(over_1000.values(),over_1000.keys(),c=tag,s=np.random.randint(100,500,N),cmap=cmap,norm=norm)
# # create the colorbar
# cb = plt.colorbar(scat, spacing='proportional',ticks=bounds)
# cb.set_label('Custom cbar')
# ax.set_title('Discrete color mappings')
# plt.show()

# %%
over_1000.items()
# Out:
# dict_items([('cities', 421), ('given', 475), ('lord', 6308), ('wicked', 308), ('speak', 481), ('called', 597), ('stood', 323), ('as', 3385), ('see', 567), ('we', 1801), ('what', 925), ('may', 990), ('your', 1714), ('cause', 308), ('wherefore', 338), ('sword', 376), ('shalt', 1589), ('took', 738), ('fire', 483), ('any', 881), ('yet', 645), ('o', 1065), ('hundred', 564), ('thy', 4506), ('into', 1924), ('peace', 397), ('Lord', 980), ('none', 342), ('hast', 1031), ('neither', 843), ('years', 498), ('go', 1421), ('way', 618), ('thus', 713), ('away', 816), ('saw', 527), ('ever', 373), ('these', 1177), ('Jesus', 897), ('bring', 705), ('if', 1542), ('david', 973), ('so', 1618), ('ye', 3864), ('eyes', 451), ('out', 2638), ('might', 455), ('them', 5840), ('him', 6025), ('up', 2221), ('servant', 449), ('make', 1023), ('art', 479), ('again', 626), ('had', 1937), ('city', 791), ('love', 306), ('evil', 565), ('burnt', 347), ('i', 8497), ('said', 3837), ('from', 3478), ('were', 2664), ('are', 2829), ('you', 2378), ('that', 12452), ('went', 1343), ('heard', 607), ('did', 970), ('which', 4251), ('congregation', 325), ('whom', 735), ('among', 881), ('keep', 356), ('work', 383), ('came', 2012), ('mouth', 377), ('priests', 361), ('pass', 804), ('hand', 1311), ('answered', 445), ('christ', 518), ('been', 310), ('days', 767), ('without', 397), ('seven', 443), ('more', 637), ('fear', 370), ('upon', 2625), ('judah', 760), ('spake', 573), ('hath', 2161), ('good', 661), ('fathers', 490), ('god', 321), ('holy', 572), ('there', 2151), ('know', 729), ('day', 1597), ('for', 8673), ('altar', 338), ('place', 641), ('father', 918), ('year', 343), ('sons', 1018), ('mine', 609), ('is', 6693), ('by', 2522), ('an', 1651), ('same', 311), ('king', 2170), ('over', 972), ('themselves', 371), ('nor', 737), ('also', 1687), ('say', 1028), ('another', 413), ('set', 660), ('voice', 465), ('sent', 665), ('first', 413), ('shall', 9565), ('saul', 373), ('than', 453), ('thou', 5276), ('house', 1867), ('do', 1291), ('cast', 483), ('brought', 834), ('God', 3709), ('saying', 1413), ('jerusalem', 695), ('four', 316), ('bread', 330), ('would', 412), ('round', 309), ('be', 6776), ('men', 1536), ('flesh', 381), ('taken', 307), ('or', 1069), ('about', 566), ('glory', 373), ('dwell', 322), ('come', 1891), ('israel', 2334), ('behold', 1281), ('eat', 607), ('cut', 307), ('sea', 358), ('one', 1887), ('things', 1072), ('even', 1347), ('against', 1606), ('name', 852), ('kings', 307), ('under', 377), ('not', 6199), ('forth', 825), ('their', 3772), ('priest', 467), ('commanded', 422), ('left', 326), ('those', 445), ('put', 883), ('done', 533), ('thee', 3434), ('how', 516), ('she', 956), ('because', 1169), ('yea', 312), ('every', 1182), ('time', 584), ('son', 2276), ('his', 8158), ('let', 1444), ('woman', 338), ('gave', 446), ('gold', 382), ('head', 333), ('heaven', 527), ('soul', 416), ('thereof', 784), ('until', 355), ('earth', 827), ('man', 2455), ('found', 380), ('but', 3865), ('own', 559), ('saith', 1206), ('thine', 886), ('made', 1346), ('down', 1028), ('himself', 481), ('give', 860), ('midst', 341), ('five', 335), ('water', 343), ('daughter', 314), ('spirit', 467), ('me', 3626), ('drink', 340), ('high', 388), ('take', 847), ('according', 766), ('words', 485), ('jacob', 338), ('sin', 417), ('this', 2646), ('heart', 775), ('toward', 338), ('moses', 810), ('egypt', 537), ('our', 1123), ('all', 5452), ('together', 425), ('am', 823), ('children', 1733), ('hear', 515), ('two', 805), ('and', 50021), ('great', 897), ('many', 524), ('off', 467), ('at', 1501), ('people', 1979), ('when', 2726), ('now', 1286), ('a', 7892), ('should', 732), ('he', 10010), ('land', 1597), ('kingdom', 320), ('side', 410), ('blood', 419), ('then', 2081), ('they', 7081), ('three', 452), ('who', 918), ('will', 3687), ('to', 13067), ('offering', 632), ('brother', 346), ('where', 379), ('life', 389), ('her', 1892), ('my', 4156), ('thousand', 495), ('therefore', 1201), ('word', 655), ('before', 1735), ('like', 630), ('in', ...

# %%
# !pip3 install --upgrade bokeh
df_plot = pd.DataFrame(columns=["X", "Y"])
x = list(over_1000.keys())
y = list(over_1000.values())
df_plot['X'] = x
df_plot['Y'] = y
# sns.lmplot('X', 'Y',data=df_plot, fit_reg=False)

# %%
df_plot.head(4)
# Out:
#          X     Y
# 0       is  6693
# 1       at  1501
# 2  another   413
# 3     days   767

# %%
"""
Simple demo of a scatter plot.
"""
import numpy as np
import matplotlib.pyplot as plt


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
from bokeh.models import HoverTool, ColumnDataSource,LogColorMapper
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
plt.figure(figsize=(10, 8))

# %%
# from scipy.stats import kendalltau
x = list(over_1000.keys())
y = list(over_1000.values())
df_bokeh = pd.DataFrame(columns=["X", "Y"])
df_bokeh["X"] = x
print(len(x))
df_bokeh["Y"] = y
print(len(y))
N = 4000
colors=["#084594"]
radii = np.random.random(size=N)
# Out:
# 283
# 283

# %%
# sns.pairplot(over_1000,x_vars=x, y_vars=y)
# output_file("rhema.html", title="Word Frequency")
p = figure()
p.circle(df_bokeh["X"],df_bokeh["Y"], radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="660e3ffd-aa68-4a01-9d14-a1c58ab09250">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="97e83e89-be8e-4150-afc0-3df25f1c6cc5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#97e83e89-be8e-4150-afc0-3df25f1c6cc5").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97e83e89-be8e-4150-afc0-3df25f1c6cc5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97e83e89-be8e-4150-afc0-3df25f1c6cc5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6e22ecc1-25c7-4a24-a9b8-505a7a03d7a7":{"roots":{"references":[{"attributes":{"overlay":{"id":"73d90eda-36a8-4f8c-83c4-f341660cfd2b","type":"BoxAnnotation"},"plot":{"id":"2154891c-823d-4d61-92a7-c33381c126ee","subtype":"Figure","type":"Plot"}},"id":"fcdb73c3-4d11-48de-92aa-4daadcba2c95","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"2154891c-823d-4d61-92a7-c33381c126ee","subtype":"Figure","type":"Plot"}},"id":"267da22c-30cd-4b00-a7a5-ed452257efa4","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y","radius","fill_color"],"data":{"fill_color":["#084594"],"radius":[0.9656382123812116,0.7723412037191314,0.41327928278930737,0.1528231837817393,0.5048838213757885,0.3946357165983544,0.4842744531188745,0.7625163602739469,0.21387221148083402,0.6149904140180119,0.8881229783239437,0.395016900246988,0.43391445264403194,0.29983387820713436,0.13114448627666941,0.41840799178524823,0.5126356841970989,0.06772377472708213,0.1464192896611778,0.6759806808385632,0.38119414716569255,0.6565021820835492,0.5398311619663039,0.4314639055710753,0.09221539250547761,0.9042342144921032,0.29548944730488136,0.13592317704445078,0.19481839408567914,0.15653796485968674,0.028620792696200548,0.06366356447165411,0.4302411750851495,0.9713206710908799,0.18949196002508673,0.8953132960323652,0.08495167437254214,0.7481539595245252,0.18518079997398362,0.6248291605226349,0.027571954710925883,0.6821020230204993,0.4197934571878783,0.6348523577006847,0.2805243254691976,0.7976398052242073,0.5004148773750379,0.8416942611775297,0.8968623783104166,0.09881187301179695,0.02511098201782236,0.4609800292469701,0.14839038080845646,0.4857421602069466,0.629867217492084,0.9163835212719309,0.3196665754632877,0.17503428932860843,0.9215102532642144,0.47614494201779456,0.5783181298448812,0.7293938510528075,0.868573770701598,0.6359368433229979,0.9998697040230129,0.7454307464528891,0.04940513446972228,0.7171634599350701,0.8101600509074692,0.845673480258591,0.6597601141009761,0.7260363485495391,0.00789225175375241,0.06460728836022656,0.03300927329323278,0.6867321241572398,0.32697774175792726,0.9182487568824984,0.3178452824554453,0.6246457533790166,0.9293603235589737,0.037308622706959005,0.7936171996612974,0.13528897776392068,0.1580321065398479,0.18290019942361402,0.8227451880454973,0.6083023826352312,0.40937035204019534,0.8742948640440651,0.3798622479456081,0.870965319413632,0.9628068364436619,0.13580626606946433,0.485412070353165,0.17786915968420258,0.9332999887551099,0.7825331926475932,0.9531669538437281,0.730338682253882,0.7223952325658977,0.7736791332460928,0.9095098839164053,0.21662635700774813,0.6791973362803863,0.9239704605935625,0.0166075296234115,0.6735143475476282,0.17924845249451937,0.20349115165222786,0.6027251482825627,0.4612729303358424,0.5512888642832192,0.6711751526466513,0.3401664043084427,0.5099027897132885,0.270723136930044,0.2230675132204769,0.7157281458177315,0.11291556617507559,0.4821146697590498,0.10413708662294019,0.8989951793459742,0.9302978180273989,0.6447507687045276,0.014798816341189625,0.09868859179617873,0.3564869800128304,0.5601819795761863,0.4993999890291153,0.8994565380959578,0.27327401674380636,0.6651348655086228,0.5604935002961793,0.23608220246314104,0.09547846526986892,0.4382906925888078,0.20406565714943403,0.5131379259101971,0.9355453633105534,0.02259489168794515,0.24079202284340917,0.9061227089353997,0.5321474902279488,0.5118285244137541,0.3238886181953826,0.7695391967335816,0.7203021060763142,0.026057339568143045,0.3773746035451969,0.23778204640809764,0.653468313968702,0.506580140571611,0.8369837722979311,0.10970805077067347,0.9367203862035016,0.652359127834488,0.8537114345533148,0.7806473480784494,0.40630392912150304,0.4072146689937337,0.7179499508189644,0.17939379117793708,0.9081380218590839,0.19247152066637752,0.5791378338244457,0.8697950605609888,0.17861398682606167,0.32142065366906614,0.11414982211820957,0.30991023885846813,0.3769446183167212,0.9882194024964556,0.8357998459844992,0.158981412915926 ...

# %%
 p = figure(title="Rhema Word Freq", x_axis_label='Word', y_axis_label='Freq')

# %%
p.line(x,y, legend="Worded", line_width=2)
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ca0e59dc-9735-4d75-8622-2e2a83626485">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d819658f-d36d-4e96-b657-8d9d678c920d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#d819658f-d36d-4e96-b657-8d9d678c920d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d819658f-d36d-4e96-b657-8d9d678c920d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd819658f-d36d-4e96-b657-8d9d678c920d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6556dac8-5093-4d3e-9890-23f95c1c9f74":{"roots":{"references":[{"attributes":{},"id":"0d1fcd40-2c3e-42e1-a1e5-1a44d08b3c91","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Freq","formatter":{"id":"0d1fcd40-2c3e-42e1-a1e5-1a44d08b3c91","type":"BasicTickFormatter"},"plot":{"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"079e90eb-3826-4a12-83ea-109c8af1afea","type":"BasicTicker"}},"id":"9338143f-f43a-48a4-88e9-5e8679bcf39f","type":"LinearAxis"},{"attributes":{"plot":{"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"}},"id":"aa4a85ec-9a62-498c-aa09-541f9f307eb4","type":"SaveTool"},{"attributes":{},"id":"079e90eb-3826-4a12-83ea-109c8af1afea","type":"BasicTicker"},{"attributes":{"overlay":{"id":"fcf35e00-c890-44dc-a66e-c70f4e13c72b","type":"BoxAnnotation"},"plot":{"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"}},"id":"a474af0a-ee2a-4ded-bd6e-fd257b7195ca","type":"BoxZoomTool"},{"attributes":{"legends":[["Worded",[{"id":"35e6783e-f800-4c5f-a454-92c78abcc37b","type":"GlyphRenderer"}]]],"plot":{"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"}},"id":"95e4a9a7-3538-43f0-856f-85d71ef3935f","type":"Legend"},{"attributes":{"axis_label":"Word","formatter":{"id":"8e4c1a35-3c26-4067-80c1-49f02bddbf5c","type":"BasicTickFormatter"},"plot":{"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"872c9623-9b1e-45b6-a5fb-544965a27e12","type":"BasicTicker"}},"id":"98468369-d49b-4b84-996f-6c6b7eaada78","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"5d356f12-b200-453d-bb69-4d064534de1d","type":"Line"},{"attributes":{},"id":"872c9623-9b1e-45b6-a5fb-544965a27e12","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Rhema Word Freq"},"id":"75ee3ab4-b7eb-4ee3-8db1-abfe58d31a47","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"079e90eb-3826-4a12-83ea-109c8af1afea","type":"BasicTicker"}},"id":"f52a9c2e-3a56-4b21-86ed-ccf8dae99d62","type":"Grid"},{"attributes":{"plot":{"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"}},"id":"2a262a22-6632-4221-af31-b87c412a8bbc","type":"PanTool"},{"attributes":{"data_source":{"id":"6ec874ac-5781-438d-89ae-03defc9099d8","type":"ColumnDataSource"},"glyph":{"id":"5d356f12-b200-453d-bb69-4d064534de1d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"e8159d1a-0620-4b78-9d6b-65cb10b499ea","type":"Line"},"selection_glyph":null},"id":"35e6783e-f800-4c5f-a454-92c78abcc37b","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"98468369-d49b-4b84-996f-6c6b7eaada78","type":"LinearAxis"}],"left":[{"id":"9338143f-f43a-48a4-88e9-5e8679bcf39f","type":"LinearAxis"}],"renderers":[{"id":"98468369-d49b-4b84-996f-6c6b7eaada78","type":"LinearAxis"},{"id":"34754302-56d7-4e6b-84bf-2b24ca39ed89","type":"Grid"},{"id":"9338143f-f43a-48a4-88e9-5e8679bcf39f","type":"LinearAxis"},{"id":"f52a9c2e-3a56-4b21-86ed-ccf8dae99d62","type":"Grid"},{"id":"fcf35e00-c890-44dc-a66e-c70f4e13c72b","type":"BoxAnnotation"},{"id":"95e4a9a7-3538-43f0-856f-85d71ef3935f","type":"Legend"},{"id":"35e6783e-f800-4c5f-a454-92c78abcc37b","type":"GlyphRenderer"}],"title":{"id":"75ee3ab4-b7eb-4ee3-8db1-abfe58d31a47","type":"Title"},"tool_events":{"id":"e5ba9ba6-9450-46a7-92d1-00674cd2db19","type":"ToolEvents"},"toolbar":{"id":"7cc5a6bd-d3b5-45a2-a193-fb4100399753","type":"Toolbar"},"x_range":{"id":"ed00ec15-30e5-4b9a-85f5-dcab3ed1485e","type":"DataRange1d"},"y_range":{"id":"06de2c88-070d-4ede-8435-8dacfdd6d8bc","type":"DataRange1d"}},"id":"e913204e-b2ec-4e4d-bf71-d60a5c3ce1ce","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"e5ba9ba6-9450-46a7-92d1-00674cd2db19","type":"ToolEvents"},{"attributes":{"callback":null},"id":"ed00ec15-30e5-4b9a-8 ...

# %%
plt.figure(figsize=(14, 10))
sns.distplot(df_bokeh["Y"], bins=20, kde=False, rug=True);
plt.show()

# %%
# sns.jointplot(x="x", y="y", data=df_bokeh);

# %%
plt.figure(figsize=(12, 10))
sns.swarmplot(x=df_bokeh["X"], y=df_bokeh["Y"], data=df_bokeh);

# %%
sns.distplot(df_bokeh["Y"], kde=False, rug=True);

# %%
sns.set()

# Load the example flights dataset and conver to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5)

# %%
sns.pairplot(df_bokeh);

# %%
import seaborn as sns; 
sns.set(style="ticks", color_codes=True)
tips = df_bokeh
g = sns.JointGrid(x="total_bill", y="tip", data=tips)

# %%
# g = sns.JointGrid(x="total_bill", y="tip", data=tips)
# g = g.plot(sns.regplot, sns.distplot)

# %%
sns.distplot(df_bokeh["Y"]);

# %%
sns.kdeplot(df_bokeh["Y"], shade=True);

# %%
# df = pd.DataFrame(over_1000)
# df = pd.DataFrame.from_dict(over_1000, orient='columns', dtype=None)
# plt.plot.area()
# sns.lmplot('x', 'y', data=df_verses, fit_reg=False)

# %%
# data = pd.read_fwf('data.txt', header = None)
data = pd.read_fwf('data.txt', names=['Books','Verse','Extras'])

len(data)
# Out:
# 31102

# %%
df_data = pd.DataFrame(data)

# %%
df_data.head()
df_heads = df_data['Books']
# books = df_data.groupby[df_data['0']]

# %%
df_heads.head()
# Out:
# 0    Genesis
# 1    Genesis
# 2    Genesis
# 3    Genesis
# 4    Genesis
# Name: Books, dtype: object
